# %%
import copy

import numpy as np
import h5py
import matplotlib.pyplot as plt

# %%
file = h5py.File('snapshots/snapshots_s3.h5', 'r')

# %%
dset = file['tasks']['b']

# %%
cmap = copy.copy(plt.cm.get_cmap("RdBu_r"))

plt.figure(figsize=(16,16))
plt.imshow(np.flip(dset[30].T, axis=0), cmap=cmap, aspect=1, vmin=-0.5, vmax=0.5)
# plt.imsave('test_imsave_v2.png', np.flip(dset[-1].T, axis=0), cmap=cmap, vmin=-0.5, vmax=0.5, dpi=100)
# plt.savefig('test_image.png', dpi=100)
